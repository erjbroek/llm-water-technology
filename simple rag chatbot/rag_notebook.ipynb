# %%
import sys
# !{sys.executable} -m pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\nyanc\anaconda3\lib\site-packages (25.2)
# Requirement already satisfied: setuptools in c:\users\nyanc\anaconda3\lib\site-packages (80.9.0)
# Requirement already satisfied: wheel in c:\users\nyanc\anaconda3\lib\site-packages (0.45.1)

# %%
import sys
# !{sys.executable} -m pip install chromadb gradio sentence-transformers PyPDF2 langchain-text-splitters torch torchvision ollama langchain
# Out:
# Requirement already satisfied: chromadb in c:\users\nyanc\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: gradio in c:\users\nyanc\anaconda3\lib\site-packages (5.49.1)
# Requirement already satisfied: sentence-transformers in c:\users\nyanc\anaconda3\lib\site-packages (5.1.1)
# Requirement already satisfied: python-pptx in c:\users\nyanc\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: PyPDF2 in c:\users\nyanc\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: langchain-text-splitters in c:\users\nyanc\anaconda3\lib\site-packages (0.3.11)
# Requirement already satisfied: torch in c:\users\nyanc\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in c:\users\nyanc\anaconda3\lib\site-packages (0.23.0)
# Requirement already satisfied: ollama in c:\users\nyanc\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: langchain in c:\users\nyanc\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: build>=1.0.3 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (2.10.3)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\nyanc\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (2.1.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\nyanc\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\nyanc\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\nyanc\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\nyanc\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\nyanc\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\nyanc\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nyanc\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nyanc\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nyanc\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nyanc\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.10.5)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.119.0)
# Requirement already satisfied: ffmpy in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.6.3)
# Requirement already satisfied: gradio-client==1.13.3 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.35.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: packaging in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydub in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.14.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: fsspec in c:\users\nyanc\anaconda3\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\nyanc\anaconda3\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nyanc\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nyanc\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nyanc\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: filelock in c:\users\nyanc\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nyanc\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nyanc\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nyanc\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\nyanc\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\nyanc\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nyanc\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\nyanc\anaconda3\lib\site-packages (from sentence-transformers) (4.57.0)
# Requirement already satisfied: scikit-learn in c:\users\nyanc\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\nyanc\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nyanc\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nyanc\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\nyanc\anaconda3\lib\site-packages (from python-pptx) (3.2.9)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from python-pptx) (5.3.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in c:\users\nyanc\anaconda3\lib\site-packages (from langchain-text-splitters) (0.3.79)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nyanc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.4.34)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nyanc\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nyanc\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nyanc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nyanc\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.23.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nyanc\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\nyanc\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: setuptools in c:\users\nyanc\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\nyanc\anaconda3\lib\site-packages (from langchain) (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nyanc\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: pyproject_hooks in c:\users\nyanc\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\nyanc\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nyanc\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nyanc\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nyanc\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\nyanc\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\nyanc\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\nyanc\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\nyanc\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\nyanc\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nyanc\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nyanc\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\nyanc\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\nyanc\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\nyanc\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\nyanc\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\nyanc\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\nyanc\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\nyanc\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\nyanc\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\nyanc\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\nyanc\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nyanc\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nyanc\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\nyanc\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\nyanc\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\nyanc\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\nyanc\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\nyanc\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nyanc\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nyanc\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nyanc\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %%
import os
import uuid
import torch
import chromadb
import gradio as gr
from sentence_transformers import SentenceTransformer
from ollama import Client
import PyPDF2
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
ollama_client = Client()
print("Ollama client initialized!")

print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)} ({torch.cuda.get_device_properties(0).total_memory/1024**3:.1f} GB)")
else:
    print("Running on CPU")
# Out:
# Ollama client initialized!
# CUDA available: False
# Running on CPU

# %%
class DocumentProcessor:
    def __init__(self):
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=200,
            length_function=len,
        )

    def extract_text_from_pdf(self, file_path: str) -> str:
        text = ""
        try:
            with open(file_path, "rb") as f:
                reader = PyPDF2.PdfReader(f)
                for page in reader.pages:
                    page_text = page.extract_text() or ""  # may return None
                    text += page_text + "\n"
            print(f"Extracted {len(text)} chars from PDF: {file_path}")
        except Exception as e:
            print(f"Error reading PDF: {e}")
        return text

    def extract_text_from_txt(self, file_path: str) -> str:
        text = ""
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                text = f.read()
            print(f"Extracted {len(text)} chars from TXT: {file_path}")
        except Exception as e:
            print(f"Error reading TXT: {e}")
        return text

    def process_document(self, file_path: str, file_type: str):
        if file_type == "pdf":
            text = self.extract_text_from_pdf(file_path)
        elif file_type == "txt":
            text = self.extract_text_from_txt(file_path)
        else:
            raise ValueError(f"Unsupported file type: {file_type}")

        if not text.strip():
            raise ValueError("No text could be extracted from document")

        chunks = self.text_splitter.split_text(text)
        print(f"✂ Split into {len(chunks)} chunks. Example: {chunks[:2]}")
        return chunks

doc_processor = DocumentProcessor()

# %%
class VectorStore:
    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.embedding_model = SentenceTransformer(
            "all-MiniLM-L6-v2", device=self.device
        )
        self.chroma_client = chromadb.Client()
        self.collection_name = "ai_ml_documents"
        try:
            self.chroma_client.delete_collection(name=self.collection_name)
        except:
            pass
        self.collection = self.chroma_client.create_collection(name=self.collection_name)
        print(f"Vector store initialized on {self.device}")

    def add_documents(self, chunks, source_file: str):
        embeddings = self.embedding_model.encode(chunks, convert_to_tensor=False)
        ids = [f"{source_file}{i}{uuid.uuid4().hex[:8]}" for i in range(len(chunks))]
        metadatas = [{"source": source_file, "chunk_id": i} for i in range(len(chunks))]
        self.collection.add(
            documents=chunks,
            embeddings=embeddings.tolist(),
            metadatas=metadatas,
            ids=ids,
        )
        print(f"Added {len(chunks)} chunks from {source_file}")

    def search(self, query: str, top_k: int = 5):
        query_embedding = self.embedding_model.encode([query])[0].tolist()
        results = self.collection.query(query_embeddings=[query_embedding], n_results=top_k)
        print(f"Search for '{query}' retrieved {len(results['documents'][0])} chunks")
        return results

    def get_collection_stats(self):
        try:
            count = self.collection.count()
            all_results = self.collection.get() if count > 0 else {"metadatas":[]}
            sources = {m.get("source","Unknown") for m in all_results["metadatas"]}
            return {
                "total_chunks": count,
                "total_documents": len(sources),
                "sources": list(sources),
                "embedding_model": "all-MiniLM-L6-v2",
                "device": self.device,
            }
        except Exception as e:
            return {"error": str(e)}

    def clear_collection(self):
        try:
            self.chroma_client.delete_collection(name=self.collection_name)
            self.collection = self.chroma_client.create_collection(name=self.collection_name)
            print("Vector collection cleared")
        except Exception as e:
            print(f"Error clearing collection: {e}")

vector_store = VectorStore()
# Out:
# Vector store initialized on cpu

# %%
class RAGChatbot:
    def __init__(self, vector_store, ollama_client):
        self.vector_store = vector_store
        self.ollama_client = ollama_client
        self.conversation_history = []

    def get_relevant_context(self, query):
        try:
            results = self.vector_store.search(query, top_k=5)
            docs = results["documents"][0]
            return "\n\n".join(docs)
        except Exception as e:
            print(f"Retrieval error: {e}")
            return ""

    def generate_response(self, query: str):
        context = self.get_relevant_context(query)
        history = "\n".join([
            f"Q: {h['question']}\nA: {h['answer']}" for h in self.conversation_history[-3:]
        ])

        prompt = f"""
You are a helpful assistant answering based ONLY on the uploaded document context.
If unsure, say so.

Conversation history:
{history}

Relevant document context:
{context}

User question: {query}
"""

        try:
            response = self.ollama_client.chat(
                model="qwen3:4b",
                messages=[{"role": "user", "content": prompt}],
                stream=False
            )
            print("DEBUG Ollama raw response:", response)

            answer = ""
            if hasattr(response, "message") and hasattr(response.message, "content"):
                answer = response.message.content
            elif isinstance(response, dict):
                message = response.get("message", {})
                if isinstance(message, dict):
                    answer = message.get("content", "")
                elif "content" in response:
                    answer = response["content"]
            else:
                answer = str(response)

            #Strip trailing whitespace
            answer = answer.strip()

            #Remove <think>...</think> sections
            if "<think>" in answer:
                try:
                    # Split off the visible portion after </think>
                    answer = answer.split("</think>")[-1].strip()
                except Exception:
                    pass

            self.conversation_history.append({"question": query, "answer": answer})
            return answer

        except Exception as e:
            return f"Error from Ollama: {e}"

    def clear_history(self):
        self.conversation_history = []
        print("Conversation history cleared")

chatbot = RAGChatbot(vector_store, ollama_client)

# %%
def get_db_stats():
    stats = vector_store.get_collection_stats()
    if "error" in stats:
        return f"DB Error: {stats['error']}"
    return f"""
Vector DB Stats:
- Documents: {stats['total_documents']}
- Chunks: {stats['total_chunks']}
- Model: {stats['embedding_model']}
- Device: {stats['device']}
Sources: {stats['sources']}
"""

def upload_and_process_files(files):
    if not files: 
        return "No files uploaded!", get_db_stats()
    messages = []
    for file in files:
        ext = file.name.split(".")[-1].lower()
        chunks = doc_processor.process_document(file.name, ext)
        vector_store.add_documents(chunks, file.name)
        messages.append(f"{file.name} ({len(chunks)} chunks)")
    return "\n".join(messages), get_db_stats()

def chat_response(message, history):
    if not message.strip():
        return history, ""
    response = chatbot.generate_response(message)
    history.append([message, response])
    return history, ""

def clear_all_data():
    vector_store.clear_collection()
    chatbot.clear_history()
    return "All data cleared!", [], get_db_stats()

# %%
with gr.Blocks(title="Document Q&A Assistant") as demo:
    gr.Markdown("# Document-Based AI Q&A")

    with gr.Row():
        with gr.Column(scale=1):
            file_upload = gr.Files(file_types=[".pdf",".txt"], file_count="multiple")
            upload_btn = gr.Button("Process Files", variant="primary")
            upload_status = gr.Textbox(label="File Status")
            db_stats = gr.Textbox(label="DB Stats", value=get_db_stats())
            clear_btn = gr.Button("Clear All Data")
            refresh_btn = gr.Button("Refresh Stats")

        with gr.Column(scale=2):
            chatbot_ui = gr.Chatbot(label="Chatbot", height=500)
            msg_box = gr.Textbox(label="Your Question")
            send_btn = gr.Button("Send")
            clear_chat_btn = gr.Button("Clear Chat")

    upload_btn.click(upload_and_process_files, file_upload, [upload_status, db_stats])
    send_btn.click(chat_response, [msg_box, chatbot_ui], [chatbot_ui, msg_box])
    msg_box.submit(chat_response, [msg_box, chatbot_ui], [chatbot_ui, msg_box])
    clear_btn.click(clear_all_data, outputs=[upload_status, chatbot_ui, db_stats])
    refresh_btn.click(get_db_stats, outputs=[db_stats])
    clear_chat_btn.click(lambda: ([], "Chat cleared!"), outputs=[chatbot_ui, upload_status])

if __name__ == "__main__":
    print("Launching Gradio...")
    demo.launch(share=True, debug=True)
# Out:
# C:\Users\nyanc\AppData\Local\Temp\ipykernel_4636\106931803.py:14: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot_ui = gr.Chatbot(label="Chatbot", height=500)
# Launching Gradio...
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
